# %% [markdown]
# # Make dataset from blobs
#
# April 25, 2021

# %% [markdown]
# - Was not impressed with how the Titanic dataset would classify in K-means
# - To move fast, I will create a fake dataset
# - In time, may want to make the data meaningul for the user 'wow'

# %%
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Make blobs

# %%
from sklearn.datasets import make_blobs

# %%
k = 3

# %%
arr = make_blobs(n_samples = 150, n_features = 2, centers = k)

# %% [markdown]
# #### There's effectively an x,y coordinate in arr[0]

# %%
arr[0].shape
# Out:
# (150, 2)

# %% [markdown]
# #### arr[1] is the cluster

# %%
arr[1].shape
# Out:
# (150,)

# %% [markdown]
# ## 2. Look at it as a dataframe

# %%
df = pd.DataFrame(arr[0])

# %%
df[2] = arr[1]

# %%
df.head()
# Out:
#           0         1  2
# 0  1.498005 -5.211325  1
# 1 -9.774655 -2.128615  2
# 2  2.652464 -6.730050  0
# 3 -7.810276  0.508696  2
# 4 -0.611612 -6.661564  1

# %% [markdown]
# ### 3. Plot clusters and iterate on random states

# %%
plt.scatter(df[0], df[1])

# %%
plt.scatter(df[0], df[1], c=df[2], cmap='rainbow')

# %% [markdown]
# ### ^^ This is too distinct... need to adjust

# %%
std = 2

arr = make_blobs(n_samples = 150, n_features = 2, cluster_std = std, centers = k, center_box = (1, 20), random_state = 54 )

a = arr[0][:,0]
b = arr[0][:,1]

plt.scatter(a, b, c=arr[1], cmap='rainbow')

# %%
fig = plt.figure(figsize=(12, 7))

plt.scatter(a, b, c=arr[1], cmap='rainbow')

# %%
fig = plt.figure(figsize=(12, 7))

plt.scatter(a, b)

# %% [markdown]
# ### ^^ This is what it will look like before clustering

# %% [markdown]
# ***

# %%
x = 54

arr = make_blobs(n_samples = 150, n_features = 2, cluster_std=1.8, centers = k, random_state = x)

a = arr[0][:,0]
b = arr[0][:,1]

plt.scatter(a, b, c=arr[1], cmap='rainbow')

# %%
x = 54
std = 2.2

arr = make_blobs(n_samples = 150, n_features = 2, cluster_std= std, centers = k, random_state = x)

a = arr[0][:,0]
b = arr[0][:,1]

fig = plt.figure(figsize=(12, 7))
plt.scatter(a, b, c=arr[1], cmap='rainbow')

# %% [markdown]
# ## 4. Preprocess and save

# %% [markdown]
# ### Process into a (150,3) nparray

# %%
arr3 = np.zeros((150,3))

arr3[:,:2] = arr[0][:,:2]

# %%
arr3[:5]
# Out:
# array([[ -9.81802597,   3.40051897,   0.        ],
#        [ -8.67748122,   9.86685892,   0.        ],
#        [ -0.87451068,  -2.80124852,   0.        ],
#        [-10.43917611,  13.66146793,   0.        ],
#        [ -4.23604601,   3.06976897,   0.        ]])

# %%
arr3[:,2] = arr[1]

# %%
arr3[:5]
# Out:
# array([[ -9.81802597,   3.40051897,   1.        ],
#        [ -8.67748122,   9.86685892,   2.        ],
#        [ -0.87451068,  -2.80124852,   0.        ],
#        [-10.43917611,  13.66146793,   2.        ],
#        [ -4.23604601,   3.06976897,   1.        ]])

# %% [markdown]
# ### Look at as a df

# %%
df = pd.DataFrame(arr3)

# %%
df.describe()
# Out:
#                 0           1           2
# count  150.000000  150.000000  150.000000
# mean    -6.210451    2.580003    1.000000
# std      3.984738    5.571658    0.819232
# min    -14.521158   -6.964162    0.000000
# 25%     -9.763429   -1.869734    0.000000
# 50%     -6.662009    1.180411    1.000000
# 75%     -2.939518    8.198913    2.000000
# max      1.844286   13.661468    2.000000

# %%
df[2].unique()
# Out:
# array([1., 2., 0.])

# %% [markdown]
# ### Save nparray

# %%
np.save('../data/blobs150_54_2-2', arr3)

# %% [markdown]
# ### Confirm save

# %%
arr = np.load('../data/blobs150_54_2-2.npy')

# %%
a = arr[:,0]
b = arr[:,1]

fig = plt.figure(figsize=(12, 7))
plt.scatter(a, b, c=arr[:,2], cmap='rainbow')
